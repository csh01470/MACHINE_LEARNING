# %% [markdown]
# # CH03.4. **Advanced Gradient Boosting Models**

# %% [markdown]
# > ## **eXtreme Gradient Boosting(XGBoost)**

# %% [markdown]
# #### **(1) 정의** :

# %% [markdown]
# #### **(2) 특징** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# #### **(3) 장점** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# #### **(4) 단점** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **LightGBM**

# %% [markdown]
# #### **(1) 정의** :

# %% [markdown]
# #### **(2) 특징** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# #### **(3) 장점** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# #### **(4) 단점** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **CatBoost**

# %% [markdown]
# #### **(1) 정의** :

# %% [markdown]
# #### **(2) 특징** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# #### **(3) 장점** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③

# %% [markdown]
# #### **(4) 단점** :
# #### $ \hspace{0.15cm} $ ①
# #### $ \hspace{0.15cm} $ ②
# #### $ \hspace{0.15cm} $ ③
